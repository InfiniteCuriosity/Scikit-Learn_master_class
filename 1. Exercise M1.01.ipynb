# %% [markdown]
# Imagine we are interested in predicting penguins species based on two of their body measurements: culmen length and culmen depth. First we want to do some data exploration to get a feel for the data.
#
# What are the features? What is the target?

# %%
from palmerpenguins import load_penguins

penguins = load_penguins()

penguins.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# How many features are numerical? How many are cetegorical?

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %% [markdown]
# The columns for species, island and sex are categorical
# The columns for bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g and year are numerical

# %% [markdown]
# What are the different species of penguin, and how many of each are there in the data set?

# %%
penguins["species"].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %% [markdown]
# Plot histograms for the numerical features

# %%
penguins.hist(figsize=(20, 14))
# Out:
# array([[<AxesSubplot: title={'center': 'bill_length_mm'}>,
#         <AxesSubplot: title={'center': 'bill_depth_mm'}>],
#        [<AxesSubplot: title={'center': 'flipper_length_mm'}>,
#         <AxesSubplot: title={'center': 'body_mass_g'}>],
#        [<AxesSubplot: title={'center': 'year'}>, <AxesSubplot: >]],
#       dtype=object)

# %% [markdown]
# Show features distribution for each class

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
sns.pairplot(penguins, hue="species")
